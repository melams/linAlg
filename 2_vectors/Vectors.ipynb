# %% [markdown]
# # Vector Nomanclature & Symbology

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# <h2>Dot Product Notations & Symbols</h2>
#
# <h3>&alpha; = v &sdot; w = v<sup>T</sup>w = &sum;<sub>i=1</sub><sup>n</sup> v<sub>i</sub>w<sub>i</sub></h3>

# %% [markdown]
# # # Algebraic Interpretation
# ## With some numpy learnings

# %%
#basic vectors and some numpy rules

vec_1d = [3, -2, 1]  # Python list  # not a numpy array, but can be used in numpy functions (internally converted to 1D array)
print("this is a 2d row vector: ", str(vec_2d))

vec_3d = [14, -31, 32]  #All vectors are python lists of x dimensions (elements) 
print("this is a 3d row vector: ", str(vec_3d))

# Tranpose - row to column - 

vec_3d_t = np.transpose(vec_3d)  
print("this is a 3d row vector transposerd: ", vec_3d_t)  # appears to do nothing to a list (vector)

# Basic numpy arrays (vectors and matrices)
array_3d = np.array([[12],[34],[22]])
print("this is a 3-dimensional array (vector) in numpy: \n", array_2d)

print("this is a transpose of an array: \n", np.transpose(array_2d))

print(np.transpose(np.transpose([[45],[33],[22]])))

print(np.transpose(vec_2d))
print(np.transpose(np.transpose(vec_2d)))
# Out:
# this is a 2d row vector:  [3, -2, 1]
# this is a 3d row vector:  [14, -31, 32]
# this is a 3d row vector transposerd:  [ 14 -31  32]
# this is a 3-dimensional array (vector) in numpy:
#  [[12]
#  [34]
#  [22]]
# this is a transpose of an array:
#  [[12 34 22]]
# [[45]
#  [33]
#  [22]]
# [ 3 -2  1]
# [ 3 -2  1]

# %% [markdown]
# # Geometric Interpretation

# %%
# plot them
plt.plot([0,vec_2d[0]],[0,vec_2d[1]])
plt.axis('equal')
plt.plot([-4, 4],[0, 0],'k--')
plt.plot([0, 0],[-4, 4],'k--')
plt.grid()
plt.axis((-4, 4, -4, 4))
plt.show()


# plot the 3D vector
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, vec_3d[0]],[0, vec_3d[1]],[0, vec_3d[2]])

# make the plot look nicer
plt.axis('equal')
ax.plot([0, 0],[0, 0],[-35, 35],'k--')
ax.plot([0, 0],[-35, 35],[0, 0],'k--')
ax.plot([-35, 35],[0, 0],[0, 0],'k--')
plt.show()
